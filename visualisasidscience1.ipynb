# %%
from scipy import stats
import pandas as pd
import seaborn as sns
sns.set(style="darkgrid")
import matplotlib.pyplot as plt

# %%
ngetest = pd.read_csv("test.csv", encoding="ISO-8859–1")
ngetest.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  458996  Female          Yes   69        No         NaN              0.0
# 3  459000    Male          Yes   59        No   Executive             11.0
# 4  459001  Female           No   19        No   Marketing              NaN
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          1.0  Cat_6
# 1        Average          4.0  Cat_6
# 2            Low          1.0  Cat_6
# 3           High          2.0  Cat_6
# 4            Low          4.0  Cat_6

# %%
ngetest2 = ngetest[ngetest["Profession"].isin(["Engineer", "Nan", "Healthcare", "Marketing", "Artist", "Lawyer"])]
ngetest2.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 4  459001  Female           No   19        No   Marketing              NaN
# 7  459008  Female          Yes   47       Yes      Artist              1.0
# 8  459013    Male          Yes   50       Yes      Artist              2.0
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          1.0  Cat_6
# 1        Average          4.0  Cat_6
# 4            Low          4.0  Cat_6
# 7        Average          3.0  Cat_6
# 8        Average          4.0  Cat_6

# %%
chart=sns.catplot(x="Profession", y="Age", hue="Gender", s=15, data=ngetest2)
chart.set_xticklabels(rotation=90)

# %%
sns.catplot(x = "Gender", y = "Age", kind = "box", data = ngetest)

# %%
sns.jointplot(x="Age", y = "Graduated", s = 50, alpha = 0.9, data = ngetest)
